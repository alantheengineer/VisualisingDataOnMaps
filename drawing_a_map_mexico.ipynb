# %%
import os
import matplotlib.pyplot as plt
import matplotlib.cm
 
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize

import pandas as pd

# %%
fig, ax = plt.subplots(figsize=(20,20))

# %%
m = Basemap(resolution='i', # c, l, i, h, f or None
            projection='merc',
            lat_0=20.0, lon_0=-100.0,
            llcrnrlon=-115.0, llcrnrlat= 15.0, urcrnrlon=-85.0, urcrnrlat=30.0)
# Out:
# /home/alan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   after removing the cwd from sys.path.

# %%
m.drawmapboundary(fill_color='#46bcec')
m.fillcontinents(color='#f2f2f2',lake_color='#46bcec')
m.drawcoastlines()

# %%
mex_states_loc=os.path.join(os.getcwd(),'_data','mexstates')
m.readshapefile(mex_states_loc,'areas')
# Out:
# /home/alan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-f82eb3857161> in <module>
#       1 mex_states_loc=os.path.join(os.getcwd(),'_data','mexstates')
# ----> 2 m.readshapefile(mex_states_loc,'areas')
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2212             self.set_axes_limits(ax=ax)
#    2213             # clip boundaries to map limbs
# -> 2214             lines,c = self._cliplimb(ax,lines)
#    2215             info = info + (lines,)
#    2216         self.__dict__[name]=coords
#
# ...

# %%
df_poly = pd.DataFrame({
        'shapes': [Polygon(np.array(shape), True) for shape in m.areas],
        'area': [area['name'] for area in m.areas_info]
    })
df_poly = df_poly.merge(new_areas, on='area', how='left')
